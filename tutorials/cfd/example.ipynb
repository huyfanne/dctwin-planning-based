# %% [markdown]
# In this case, we will conduct a CFD simulation for a data center with one CRAC unit and 20 racks without containment.

# %%
from dctwin.interfaces import CFDManager
from dctwin.models import Room
from dctwin.utils import config
from pathlib import Path

# %% [markdown]
# (1) Configure environment variable (log save dir) and read room geometry file

# %%
config.CASE_DIR = Path("log/tmp").absolute()
room = Room.load("model/geometry/room.json")
config.PRESERVE_FOAM_LOG = True

# %% [markdown]
# (2) Build CFDManager and run CFD simulation

# %%
manager = CFDManager(room=room)
manager.run()
# Out:
# 2023-03-29 05:44:49.393 | INFO     | dctwin.backends.rom.pod.core:load:318 - POD data not found. Run simulation with CFD backend.
# 2023-03-29 05:44:49.394 | INFO     | dctwin.interfaces.managers.cfd_manager:build_geometry:142 - start building geometry ...
# 2023-03-29 05:44:49.404 | INFO     | dctwin.backends.core:run_container:68 - docker mount: /home/ryan_wong/dctwin/tutorials/cfd/log/base
# 2023-03-29 05:44:49.404 | INFO     | dctwin.backends.core:run_container:69 - docker run: bash -c salome start -t geometry_script.py && chown -R 1003:1004 /data
# 2023-03-29 05:44:50.420 | INFO     | dctwin.backends.core:run_container:102 - runSalome running on 0ed9bdf78590
# 2023-03-29 05:44:50.426 | INFO     | dctwin.backends.core:run_container:102 - INFO:MainThread:/opt/salome/BINARIES-UB18.04/KERNEL/bin/salome/PortManager.py[158]Problem loading PortManager file: /tmp/.salome_PortManager.cfg
# 2023-03-29 05:44:50.426 | INFO     | dctwin.backends.core:run_container:102 - INFO:PortManager:Problem loading PortManager file: /tmp/.salome_PortManager.cfg
# 2023-03-29 05:44:50.440 | INFO     | dctwin.backends.core:run_container:102 - Searching for a free port for naming service: 2810 - OK
# 2023-03-29 05:44:50.633 | INFO     | dctwin.backends.core:run_container:102 - omniNames: (0) 2023-03-29 05:44:50.633560: -ORBendPoint option overriding default endpoint.
# 2023-03-29 05:44:50.730 | INFO     | dctwin.backends.core:run_container:102 - Searching Naming Service  + found in 0.1 seconds
# 2023-03-29 05:44:51.245 | INFO     | dctwin.backends.core:run_container:102 - Searching /Registry in Naming Service  + found in 0.5 seconds
# 2023-03-29 05:44:51.246 | INFO     | dctwin.backends.core:run_container:102 - th. 139940947568448 - Trace /volatile/salome/jenkins/workspace/Salome9_UB18/SALOME-9.4.0-UB18.04/SOURCES/KERNEL/src/ModuleCatalog/SALOME_ModuleCatalog_Server.cxx [101] : Module Catalog Server: Naming Service was found
# 2023-03-29 05:44:51.253 | INFO     | dctwin.backends.core:run_container:102 - Warning: this type (SALOME_MED/MEDCouplingFieldDoubleCorbaInterface,objref) already exists, it will be ignored.
# 2023-03-29 05:44:51.254 | INFO     | dctwin.backends.core:run_container:102 - Warning: this type (Study,objref) already exists, it will be ignored.
# 2023-03-29 05:44:51.749 | INFO     | dctwin.backends.core:run_container:102 - Searching /Kernel/ModulCatalog in Naming Service  + found in 0.5 seconds
# 2023-03-29 05:44:51.750 | INFO     | dctwin.backends.core:run_container:102 - RunStudy
# 2023-03-29 05:44:52.259 | INFO     | dctwin.backends.core:run_container:102 - Searching /Study in Naming Service  + found in 0.5 seconds
# 2023-03-29 05:44:52.586 | INFO     | dctwin.backends.core:run_container:102 - Warning, no type found for resource "localhost", using default value "single_machine"
# 2023-03-29 05:44:57.948 | INFO     | dctwin.backends.core:run_container:102 - Searching /Containers/0ed9bdf78590/FactoryServer in Naming Service  ++ found in 1.0 seconds
# 2023-03-29 05:44:57.948 | INFO     | dctwin.backends.core:run_container:102 - Start SALOME, elapsed time :   2.6 seconds
# 2023-03-29 05:44:58.003 | INFO     | dctwin.backends.geometry.salome:_run_backend:60 - ***** Geometry finished *****
#
#
# 2023-03-29 05:44:58.004 | INFO     | dctwin.interfaces.managers.cfd_manager:mesh:151 - start meshing geometry ...
# hello from here
# {'opening_1': Opening(location=Vertex(x=8.658, y=5.46, z=0.0), size=Size(x=0.867, y=2.172, z=0.0), velocity=Size(x=0.0, y=0.0, z=1.0)), 'opening_2': Opening(location=Vertex(x=8.658, y=3.06, z=0.0), size=Size(x=0.867, y=2.172, z=0.0), velocity=None), 'opening_3': Opening(location=Vertex(x=4.3, y=7.03, z=0.0), size=Size(x=3.0, y=0.6, z=0.0), velocity=None), 'opening_4': Opening(location=Vertex(x=4.3, y=2.83, z=0.0), size=Size(x=3.0, y=0.6, z=0.0), velocity=None)}
# ---------------------------------------------------------------------------
# TemplateSyntaxError                       Traceback (most recent call last)
# File ~/dctwin/dctwin/interfaces/managers/cfd_manager.py:152, in CFDManager.mesh(self)
#     151     logger.info("start meshing geometry ...")
# --> 152     self.mesh_backend.run(
#     153         room=self.room,
#     154         process_num=self.mesh_process,
#     155         field_config=self.field_config,
#     156     )
#     157 except Exception:
#
# File ~/dctwin/dctwin/backends/foam/snappyhex.py:54, in SnappyHexBackend.run(self, room, process_num, field_config)
#      53 generate_block_dict(room)
# ---> 54 generate_snappy_dict(
#      55     room=room, process_num=self.process_num, field_config=field_config
#      56 )
#      57 if config.cfd.dry_run:
#
# File ~/dctwin/dctwin/backends/foam/utils.py:271, in generate_snappy_dict(room, field_config, process_num)
#     269 with open(Path(config.cfd.case_dir, "system/fvOptions"), "w") as f:
#     270     f.write(
# --> 271         template_env.get_template(f"system/steady/fvOptions.j2").render(
#     272             perforated_openings=perforated_openings,
#     273         )
#     274     )
#     275 with open(Path(config.cfd.case_dir, "system/topoSetDict"), "w") as f:
#
# File ~/.cache/pypoetry/virtualenvs/dctwin-VO7daGEv-py3.10/lib/python3.10/site-packages/jinja2/environment.py:1010, in Environment.get_template(self, name, parent, globals)
#    1008     name = self.join_path(name, parent)
# -> 1010 return self._load_template(name, globals)
#
# File ~/.cache/pypoetry/virtualenvs/dctwin-VO7daGEv-py3.10/lib/python3.10/site-packages/jinja2/environment.py:969, in Environment._load_template(self, name, globals)
#     967         return template
# --> 969 template = self.loader.load(self, name, self.make_globals(globals))
#     971 if self.cache is not None:
#
# File ~/.cache/pypoetry/virtualenvs/dctwin-VO7daGEv-py3.10/lib/python3.10/site-packages/jinja2/loaders.py:138, in BaseLoader.load(self, environment, name, globals)
#     137 if code is None:
# --> 138     code = environment.compile(source, name, filename)
#     140 # if the bytecode cache is available and the bucket doesn't
#     141 # have a code so far, we give the bucket the new code and put
#     142 # it back to the bytecode cache.
#
# File ~/.cache/pypoetry/virtualenvs/dctwin-VO7daGEv-py3.10/lib/python3.10/site-packages/jinja2/environment.py:768, in Environment.compile(self, source, name, filename, raw, defer_init)
#     767 except TemplateSyntaxError:
# --> 768     self.handle_exception(source=source_hint)
#
# File ~/.cache/pypoetry/virtualenvs/dctwin-VO7daGEv-py3.10/lib/python3.10/site-packages/jinja2/environment.py:936, in Environment.handle_exception(self, source)
#     934 from .debug import rewrite_traceback_stack
# --> 936 raise rewrite_traceback_stack(source=source)
#
# File ~/dctwin/dctwin/templates/system/steady/fvOptions.j2:32, in template()
#      31 {% for key, perforated_opening in perforated_openings.items() %}
# ---> 32 airDeflection{%perforated_opening.id%}
#      33
#
# TemplateSyntaxError: Encountered unknown tag 'perforated_opening'. Jinja was looking for the following tags: 'endfor' or 'else'. The innermost block that needs to be closed is 'for'.
#
# During handling of the above exception, another exception occurred:
#
# MeshBuildError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 manager = CFDManager(room=room)
# ----> 2 manager.run()
#
# File ~/dctwin/dctwin/interfaces/managers/cfd_manager.py:220, in CFDManager.run(self, case_idx, episode_idx, save_mesh_index, save_boundary_conditions, **boundary_conditions)
#     218     self.build_geometry()
#     219 if run_mesh:
# --> 220     self.mesh()
#     221     if save_mesh_index and self.object_mesh_index is None:
#     222         self.object_mesh_index = calc_object_mesh_index(
#     223             room=self.room, mesh_points=read_mesh_coordinates(),
#     224         )
#
# File ~/dctwin/dctwin/interfaces/managers/cfd_manager.py:158, in CFDManager.mesh(self)
#     152     self.mesh_backend.run(
#     153         room=self.room,
#     154         process_num=self.mesh_process,
#     155         field_config=self.field_config,
#     156     )
#     157 except Exception:
# --> 158     raise MeshBuildError("Failed to mesh geometry")
#
# MeshBuildError:
